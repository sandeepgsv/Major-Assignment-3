# %%
# Importing the necessary libraries
import pandas as pd
import networkx as nx
from itertools import combinations
import json
from networkx.readwrite import json_graph

# %%
#Read The CSV FILE
Dt = pd.read_csv('data_scopus.csv')

# %%
#Remove the uncessary colums
Uncessary_columns = ['Conference name', 'Conference date', 'Abstract', 'Abbreviated Source Title']
Dt.drop(columns=Uncessary_columns, inplace=True)

# %%
# Remove the rows with missing values in sepecific columns
Specific_columns = ['Authors', 'Authors with affiliations', 'Year', 'Publisher']
Dt = Dt.dropna(subset=Specific_columns).copy()

# %%
#Fill NaN Values in 'Cited by' with 0
Dt['Cited by'].fillna(0, inplace=True)

# %%
#Display Top 5 rows
Dt.head(5)
# Out:
#                                                Title  Year  \
# 0  Virtual reality applications for the built env...  2020
# 1  Self-tracking while doing sport: Comfort, moti...  2020
# 2  Bridge damage: Detection, IFC-based semantic e...  2020
# 3  VR system for spatio-temporal visualization of...  2019
# 4  DiseaSE: A biomedical text analytics system fo...  2019
#
#                   EID            Publisher  \
# 0  2-s2.0-85086464158        Elsevier B.V.
# 1  2-s2.0-85082875828       Academic Press
# 2  2-s2.0-85078194587        Elsevier B.V.
# 3  2-s2.0-85075706132             Springer
# 4  2-s2.0-85074886243  Academic Press Inc.
#
#                                              Authors  \
# 0        Zhang Y., Liu H., Kang S.-C., Al-Hussein M.
# 1                               Rapp A., Tirabeni L.
# 2  Isailović D., Stojanovic V., Trapp M., Richter...
# 3  Okada K., Yoshida M., Itoh T., Czauderna T., S...
# 4               Abulaish M., Parwez M.A., Jahiruddin
#
#                                         Author(s) ID  \
# 0    57202536919;53984550800;57215426514;6603541102;
# 1                           23398572100;57191836654;
# 2  57205293410;56421700900;24831175200;3619515940...
# 3  57201502480;57171240600;35373203100;2592569550...
# 4                6505934038;57202719622;35590173900;
#
#                            Authors with affiliations  \
# 0  Zhang, Y., Department of Civil and Environment...
# 1  Rapp, A., Computer Science Department, Univers...
# 2  Isailović, D., Department for Construction Pro...
# 3  Okada, K., Ochanomizu University, Tokyo, Japan...
# 4  Abulaish, M., Department of Computer Science, ...
#
#                                       Source title  Cited by
# 0                       Automation in Construction       0.0
# 1  International Journal of Human Computer Studies       0.0
# 2                       Automation in Construction       0.0
# 3                Multimedia Tools and Applications       0.0
# 4                Journal of Biomedical Informatics       0.0

# %%
def first_author(x):
    try:
        Countries = [aff.split(",")[-1].strip() for aff in x.split(";")]
        return ','.join(Countries)
    except Exception as ex:
        print(x)

# %%
Dt['Author_Countries'] = Dt['Authors with affiliations'].apply(first_author)
Dt.head()
# Out:
#                                                Title  Year  \
# 0  Virtual reality applications for the built env...  2020
# 1  Self-tracking while doing sport: Comfort, moti...  2020
# 2  Bridge damage: Detection, IFC-based semantic e...  2020
# 3  VR system for spatio-temporal visualization of...  2019
# 4  DiseaSE: A biomedical text analytics system fo...  2019
#
#                   EID            Publisher  \
# 0  2-s2.0-85086464158        Elsevier B.V.
# 1  2-s2.0-85082875828       Academic Press
# 2  2-s2.0-85078194587        Elsevier B.V.
# 3  2-s2.0-85075706132             Springer
# 4  2-s2.0-85074886243  Academic Press Inc.
#
#                                              Authors  \
# 0        Zhang Y., Liu H., Kang S.-C., Al-Hussein M.
# 1                               Rapp A., Tirabeni L.
# 2  Isailović D., Stojanovic V., Trapp M., Richter...
# 3  Okada K., Yoshida M., Itoh T., Czauderna T., S...
# 4               Abulaish M., Parwez M.A., Jahiruddin
#
#                                         Author(s) ID  \
# 0    57202536919;53984550800;57215426514;6603541102;
# 1                           23398572100;57191836654;
# 2  57205293410;56421700900;24831175200;3619515940...
# 3  57201502480;57171240600;35373203100;2592569550...
# 4                6505934038;57202719622;35590173900;
#
#                            Authors with affiliations  \
# 0  Zhang, Y., Department of Civil and Environment...
# 1  Rapp, A., Computer Science Department, Univers...
# 2  Isailović, D., Department for Construction Pro...
# 3  Okada, K., Ochanomizu University, Tokyo, Japan...
# 4  Abulaish, M., Department of Computer Science, ...
#
#                                       Source title  Cited by  \
# 0                       Automation in Construction       0.0
# 1  International Journal of Human Computer Studies       0.0
# 2                       Automation in Construction       0.0
# 3                Multimedia Tools and Applications       0.0
# 4                Journal of Biomedical Informatics       0.0
#
#                                 Author_Countries
# 0             Canada,United States,Canada,Canada
# 1                                    Italy,Italy
# 2  Serbia,Germany,Germany,Germany,Serbia,Germany
# 3          Japan,Japan,Japan,Australia,Australia
# 4                              India,India,India

# %%
import networkx as nx

# Create a graph
G = nx.Graph()

# Dictionary to store nodes with author_id as the key
nodes_dict = {}

# Iterate through the DataFrame
for _, row in Dt.iterrows():
    author_ids = row['Author(s) ID'].split(';')
    countries = row['Author_Countries'].split(',')
    names = row['Authors'].split(',')
    i = -1
    for author_id in author_ids:
        if author_id not in nodes_dict:
            nodes_dict[author_id] = {
                "Name": names[i].strip(),
                "country": countries[i],
                "num_publications": 0,
                "num_citations": 0,
                "degree": 0,
                "id": author_id
            }
       
        i += 1

        # Update node information
        nodes_dict[author_id]["num_publications"] += 1
        nodes_dict[author_id]["num_citations"] += row['Cited by']
        nodes_dict[author_id]["degree"] += len(author_ids) - 1

# Convert the dictionary values to a list
nodes = list(nodes_dict.values())

print(nodes)
# Out:
# [{'Name': 'Al-Hussein M.', 'country': 'Canada', 'num_publications': 1, 'num_citations': 0.0, 'degree': 4, 'id': '57202536919'}, {'Name': 'Zhang Y.', 'country': 'Canada', 'num_publications': 2, 'num_citations': 19.0, 'degree': 8, 'id': '53984550800'}, {'Name': 'Liu H.', 'country': 'United States', 'num_publications': 1, 'num_citations': 0.0, 'degree': 4, 'id': '57215426514'}, {'Name': 'Kang S.-C.', 'country': 'Canada', 'num_publications': 2, 'num_citations': 19.0, 'degree': 8, 'id': '6603541102'}, {'Name': 'Al-Hussein M.', 'country': 'Canada', 'num_publications': 341, 'num_citations': 4673.0, 'degree': 1133, 'id': ''}, {'Name': 'Tirabeni L.', 'country': 'Italy', 'num_publications': 2, 'num_citations': 50.0, 'degree': 4, 'id': '23398572100'}, {'Name': 'Rapp A.', 'country': 'Italy', 'num_publications': 1, 'num_citations': 0.0, 'degree': 2, 'id': '57191836654'}, {'Name': 'Döllner J.', 'country': 'Germany', 'num_publications': 1, 'num_citations': 0.0, 'degree': 6, 'id': '57205293410'}, {'Name': 'Isailović D.', 'country': 'Serbia', 'num_publications': 1, 'num_citations': 0.0, 'degree': 6, 'id': '56421700900'}, {'Name': 'Stojanovic V.', 'country': 'Germany', 'num_publications': 1, 'num_citations': 0.0, 'degree': 6, 'id': '24831175200'}, {'Name': 'Trapp M.', 'country': 'Germany', 'num_publications': 1, 'num_citations': 0.0, 'degree': 6, 'id': '36195159400'}, {'Name': 'Richter R.', 'country': 'Germany', 'num_publications': 1, 'num_citations': 0.0, 'degree': 6, 'id': '6507346536'}, {'Name': 'Hajdin R.', 'country': 'Serbia', 'num_publications': 1, 'num_citations': 0.0, 'degree': 6, 'id': '6602981892'}, {'Name': 'Stephens K.', 'country': 'Australia', 'num_publications': 1, 'num_citations': 0.0, 'degree': 5, 'id': '57201502480'}, {'Name': 'Okada K.', 'country': 'Japan', 'num_publications': 1, 'num_citations': 0.0, 'degree': 5, 'id': '57171240600'}, {'Name': 'Yoshida M.', 'country': 'Japan', 'num_publications': 1, 'num_citations': 0.0, 'degree': 5, 'id': '35373203100'}, {'Name': 'Itoh T.', 'country': 'Japan', 'num_publications': 1, 'num_citations': 0.0, 'degree': 5, 'id': '25925695500'}, {'Name': 'Czauderna T.', 'country': 'Australia', 'num_publications': 1, 'num_citations': 0.0, 'degree': 5, 'id': '57200282319'}, {'Name': 'Jahiruddin', 'country': 'India', 'num_publications': 1, 'num_citations': 0.0, 'degree': 3, 'id': '6505934038'}, {'Name': 'Abulaish M.', 'country': 'India', 'num_publications': 1, 'num_citations': 0.0, 'degree': 3, 'id': '57202719622'}, {'Name': 'Parwez M.A.', 'country': 'India', 'num_publications': 1, 'num_citations': 0.0, 'degree': 3, 'id': '35590173900'}, {'Name': 'Hammad A.', 'country': 'Canada', 'num_publications': 1, 'num_citations': 4.0, 'degree': 2, 'id': '14628356000'}, {'Name': 'El Ammari K.', 'country': 'Canada', 'num_publications': 2, 'num_citations': 95.0, 'degree': 5, 'id': '7006162997'}, {'Name': 'Lian Y.N.', 'country': 'China', 'num_publications': 2, 'num_citations': 1.0, 'degree': 12, 'id': '57204951915'}, {'Name': 'Yang S.Y.', 'country': 'China', 'num_publications': 3, 'num_citations': 1.0, 'degree': 19, 'id': '36656019700'}, {'Name': 'Jiang R.G.', 'country': 'China', 'num_publications': 3, 'num_citations': 1.0, 'degree': 19, 'id': '8399981200'}, {'Name': 'Xie J.C.', 'country': 'China', 'num_publications': 2, 'num_citations': 1.0, 'degree': 13, 'id': '57196119394'}, {'Name': 'Yu X.', 'country': 'China', 'num_publications': 3, 'num_citations': 1.0, 'degree': 19, 'id': '57204952424'}, {'Name': 'Liang J.C.', 'country': 'China', 'num_publications': 1, 'num_citations': 1.0, 'degree': 6, 'id': '57213421778'}, {'Name': 'Lakshmi V.', 'country': 'United States', 'num_publications': 1, 'num_citations': 3.0, 'degree': 9, 'id': '57210571032'}, {'Name': 'McDonald S.', 'country': 'United States', 'num_publications': 1, 'num_citations': 3.0, 'degree': 9, 'id': '36995837100'}, {'Name': 'Mohammed I.N.', 'country': 'United States', 'num_publications': 1, 'num_citations': 3.0, 'degree': 9, 'id': '6603639150'}, {'Name': 'Bo ...

# %%
for node in nodes:
    G.add_node(node["id"], **node)

print(G.nodes(Dt=True))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 4
#       1 for node in nodes:
#       2     G.add_node(node["id"], **node)
# ----> 4 print(G.nodes(Dt=True))
#
# TypeError: NodeView.__call__() got an unexpected keyword argument 'Dt'

# %%
edges = []

for _, row in Dt.iterrows():
    if ";" in row['Author(s) ID']:
        authors = row['Author(s) ID'][:-1].split(";")
        for i, author1 in enumerate(authors):
            for j in range(i + 1, len(authors)):
                edges.append((author1, authors[j]))
    else:
        continue

# %%
G.add_edges_from(edges)
print(G.edges(data=True))
# Out:
